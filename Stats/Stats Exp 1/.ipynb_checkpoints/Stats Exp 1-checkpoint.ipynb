# %%
import pandas as pd
import numpy as np
from scipy.stats import trim_mean
from statsmodels import robust
import wquantiles

import seaborn as sns
import matplotlib.pylab as plt

# %%
df = pd.read_csv('./IT Salary Survey EU 2018.csv')

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position', 'Years of experience',
#        'Your level', 'Current Salary', 'Salary one year ago',
#        'Salary two years ago', 'Are you getting any Stock Options?',
#        'Main language at work', 'Company size', 'Company type'],
#       dtype='object')

# %%
df.drop(['Timestamp', 'City', 'Your level', 'Salary one year ago', 'Salary two years ago', 'Are you getting any Stock Options?', 'Company size', 'Company type'], axis=1)
# Out:
#       Age Gender                       Position  Years of experience  \
# 0    43.0      M                   QA Ingenieur                 11.0
# 1    33.0      F  Senior PHP Magento developer                   8.0
# 2    32.0      M              Software Engineer                 10.0
# 3    25.0      M      Senior Frontend Developer                  6.0
# 4    39.0      M                    UX Designer                 10.0
# ..    ...    ...                            ...                  ...
# 760  40.0      M          Java Developer junior                  1.0
# 761   NaN      M              E.g. C# Developer                  1.0
# 762   NaN      M              E.g. C# Developer                  1.0
# 763   NaN    NaN                            NaN                  NaN
# 764  31.0      F                            Pm                  10.0
#
#      Current Salary Main language at work
# 0           77000.0               Deutsch
# 1           65000.0               Deutsch
# ...

# %%
df.rename(columns = {'Current Salary':'salary', 'Years of experience':'experience', 'Main language at work':'lang'}, inplace = True)

# %%
df.fillna(df.median(), inplace=True)
# Out:
# C:\Users\dyota\AppData\Local\Temp\ipykernel_18920\3604797450.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.median(), inplace=True)

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 686 entries, 0 to 764
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           686 non-null    object
#  1   Age                                 686 non-null    float64
#  2   Gender                              686 non-null    object
#  3   City                                686 non-null    object
#  4   Position                            686 non-null    object
#  5   experience                          686 non-null    float64
#  6   Your level                          686 non-null    object
#  7   salary                              686 non-null    float64
#  8   Salary one year ago                 686 non-null    float64
#  9   Salary two years ago                686 non-null    float64
#  10  Are you getting any Stock Options?  686 non-null    object
# ...

# %% [markdown]
# # Estimate of Location
# ## Location estimate of price and number of reviews

# %% [markdown]
# ### _Mean_

# %%
mean_salary = df['salary'].mean()
trimmed_mean_salary = trim_mean(df['salary'], 0.1)
weighted_mean_salary = np.average(df['salary'], weights=df['experience'])

print(f'Mean price = ${mean_salary}')
print(f'Trimmed mean price = ${trimmed_mean_salary}')
print(f'Weighted mean price = ${weighted_mean_salary}')
# Out:
# Mean price = $67907.03206997084
# Trimmed mean price = $66543.78181818181
# Weighted mean price = $71915.2170343766

# %% [markdown]
# ### _Median_

# %%
median_salary = df['salary'].median()
weighted_median_salary = wquantiles.median(df['salary'], weights=df['experience'])

print(f'Median price = ${median_salary}')
print(f'Weighted median price = ${weighted_median_salary}')
# Out:
# Median price = $65000.0
# Weighted median price = $70000.0

# %% [markdown]
# ## Estimates of Variablity

# %%
print(f'Standard Deviation = {df["salary"].std()}')
print(f'Median Absolute Deviation = {robust.scale.mad(df["salary"])}')
# Out:
# Standard Deviation = 19485.25344692599
# Median Absolute Deviation = 14826.02218505602

# %% [markdown]
# ## Percentile and Boxplot

# %%
print(df['salary'].quantile([0.05, 0.25, 0.5, 0.75, 0.95]))
# Out:
# 0.05     40200.0
# 0.25     57000.0
# 0.50     65000.0
# 0.75     75000.0
# 0.95    101500.0
# Name: salary, dtype: float64

# %%
ax = (df['salary']/1000).plot.box(figsize=(3, 4), color='black',  patch_artist = True, boxprops = dict(facecolor = "#ffae77"), medianprops=dict(color='red'))
ax.set_ylabel('salary (thousands)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Frequency table and Histogram

# %%
binnedPopulation = pd.cut(df['salary'], 10)
print(binnedPopulation.value_counts())
# Out:
# (60010.0, 76580.0]      267
# (43440.0, 60010.0]      215
# (76580.0, 93150.0]      107
# (26870.0, 43440.0]       37
# (93150.0, 109720.0]      21
# (109720.0, 126290.0]     18
# (126290.0, 142860.0]     11
# (10134.3, 26870.0]        8
# (159430.0, 176000.0]      2
# (142860.0, 159430.0]      0
# Name: salary, dtype: int64

# %%
ax = (df["salary"]/1000).plot.hist(figsize=(7, 4), color='#ffae77', edgecolor='black')
ax.set_xlabel('salary (thousands)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Density Estimate

# %%
ax = df['experience'].plot.hist(density=True, xlim=[0, 12], bins=range(1,12), figsize=(5, 4), color='#ffae77',edgecolor='black')
df['experience'].plot.density(ax=ax, color='red')
ax.set_xlabel('Experience')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exploring Binary and Categorical Data

# %%
print(df["Gender"].unique())
print(df["lang"].unique())
# Out:
# ['M' 'F']
# ['Deutsch' 'English' 'Russian' 'French'
#  'Team - Russian; Cross-team - English;' 'Polish' 'Deutsch/Englisch']

# %%
ax = df.boxplot(column='salary', by='Gender', figsize=(5, 4), color='black',  patch_artist = True, boxprops = dict(facecolor = "#ffae77"), medianprops=dict(color='red'))
ax.set_xlabel('Gender')
ax.set_ylabel('Salary')
plt.title('Salary Distribution by Gender')

plt.suptitle('')
plt.tight_layout()
plt.show()

# %%
language_salary_mean = df.groupby('lang')['salary'].mean()

ax = language_salary_mean.plot(kind='bar', figsize=(5, 5), color='#ffae77', edgecolor="black")

ax.set_xlabel('Language')
ax.set_ylabel('Average Salary')
plt.title('Average Salary by Language')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatterplots

# %%
ax = df.plot.scatter(x='salary', y='experience', figsize=(6, 4), marker='$\u25EF$', color='#ffa061')
ax.set_xlabel('Salary')
ax.set_ylabel('Experience')
ax.axhline(0, color='grey', lw=1)
ax.axvline(0, color='grey', lw=1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hexagonal binning and Contour

# %%
ax = df.plot.hexbin(x='salary', y='Age', gridsize=30, sharex=False, figsize=(5, 4), cmap='Oranges')
ax.set_xlabel('Salary')
ax.set_ylabel('Age')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4, 4))
sns.kdeplot(data=df, x='salary', y='Age', ax=ax, color='#ffa061')
ax.set_xlabel('Salary')
ax.set_ylabel('Age')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical and Numeric Data

# %%
position_counts = df['Position'].value_counts()
top_5_positions = position_counts.head(5).index
df_top_5_positions = df[df['Position'].isin(top_5_positions)]

ax = df_top_5_positions.boxplot(by='Position', column='salary', figsize=(5, 6), color='black', patch_artist=True, boxprops=dict(facecolor="#ffae77"), medianprops=dict(color='red'))
ax.set_xlabel('')
ax.set_ylabel('Salary')
plt.suptitle('')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.violinplot(data=df, x='lang', y='salary',ax=ax, inner='quartile', color='#ffae77')
ax.set_xlabel('')
ax.set_ylabel('Salary')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
